# %% [markdown]
# ### Naming the variables

# %%
a = 2

# %%
type(a)
# Out:
# int

# %%
a = 2.0

# %%
type(a)
# Out:
# float

# %%
a = 2 + 4j

# %%
type(a)
ue
# Out:
# complex

# %%
a = True

# %%
type(a)
# Out:
# bool

# %%
a = False

# %%
type(a)
# Out:
# bool

# %%
2Myvariable
# Out:
#   Cell In[11], line 1
#     2Myvariable
#     ^
# SyntaxError: invalid decimal literal

# %%
2Myvariable = 2
# Out:
#   Cell In[12], line 1
#     2Myvariable = 2
#     ^
# SyntaxError: invalid decimal literal

# %%
$myvariable = 2
# Out:
#   Cell In[13], line 1
#     $myvariable = 2
#     ^
# SyntaxError: invalid syntax

# %%
_var = 2

# %%
a = 2 + 2

# %%
a
# Out:
# 4

# %%
a = 8 / 2

# %%
a
# Out:
# 4.0

# %%
b = 4.5

# %%
a + b
# Out:
# 8.5

# %%
x = 2

# %%
y = 3

# %%
z = 5

# %%
a = x**2 + 5*x - (3*y**2)/2 + z

# %%
a
# Out:
# 5.5

# %%
x = -11

# %%
y = -100

# %%
z = -1.5 * 10**(-4)

# %%
a = -3.14*3.14 + 7*z**2-9*x**2+(1/y**2)+(2/z**3)

# %%
a
# Out:
# -592592593691.4519

# %%
import math

# %%
math.exp(3)
# Out:
# 20.085536923187668

# %%
math.pow(2,3,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 math.pow(2,3,3)
#
# TypeError: pow expected 2 arguments, got 3

# %%
pow(2,3,3)
# Out:
# 2

# %%
math.log(2,10)
# Out:
# 0.30102999566398114

# %%
math.log(2)
# Out:
# 0.6931471805599453

# %%
x = -5

# %%
z = -10-(4)

# %%
a = 2*math.exp(-10)*math.log(3*z**(-2))+math.log(z,10) + math.log(1/math.exp(-x,2)+math.log((math.exp(-10),10))
# Out:
#   Cell In[55], line 1
#     a = 2*math.exp(-10)*math.log(3*z**(-2))+math.log(z,10) + math.log(1/math.exp(-x,2)+math.log((math.exp(-10),10))
#                                                                                                                    ^
# SyntaxError: incomplete input

# %%
a = 2*math.exp(-10)

# %%
a
# Out:
# 9.079985952496971e-05

# %%
b = math.log(z,10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 b = math.log(z,10)
#
# ValueError: math domain error

# %%
b = math.log(z,10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 b = math.log(z,10)
#
# ValueError: math domain error

# %%
z = 2

# %%
b = math.log(z,10)

# %%
b
# Out:
# 0.30102999566398114

# %%
c = math.log(1/(math.exp(-x)),2)

# %%
d = math.log(math.exp(x)/(math.exp(x)+1),10)

# %%
e = a + b + c + d

# %%
e
# Out:
# -9.086743257230452

# %%
x = 2

# %%
a = math.exp(-9)+1/(math.exp(x + 2))

# %%
b = math.log(math.exp(x),10)/math.log(math.exp(x))

# %%
c = a + math.log(b,2)

# %%
c
# Out:
# -1.1848154240069013

# %%
x = 2

# %% [markdown]
# ### Assignment

# %% [markdown]
# #### Q1. 3e^-2.log10(5.2^-1)+log10(3)+log3(1/e^-x)

# %%
x = 2

# %%
import math

# %%
term1_q1 = 3 * math.exp(-2) * math.log10(5 * 2**-1)

# %%
term2_q1 = math.log10(3)

# %%
term3_q1 = math.log(1 / math.exp(-x),3)

# %%
result_q1 = term1_q1 + term2_q1 + term3_q1

# %%
result_q1
# Out:
# 3.369404905954606

# %% [markdown]
# #### Q2. log10(e^x / e^(x+2)) + log_5(25) - 2e^(-3) * log10(2^3)

# %%
x = 1

# %%
term1_q2 = math.log10(math.exp(x) / math.exp(x + 2))

# %%
term2_q2 = math.log(25, 5)

# %%
term3_q2 =  2 * math.exp(-3) * math.log10(2**3)

# %%
result_q2 = term1_q2 + term2_q2 - term3_q2

# %%
result_q2
# Out:
# 1.041486630344094

# %% [markdown]
# #### Q3. log_2(1 / e^(-x)) + log10(4) - e^(-1) * log10(3 * 2^-2)

# %%
x = 3

# %%
term1_q3 = math.log(1 / math.exp(-x),2)

# %%
term2_q3 = math.log10(4)

# %%
term3_q3 = math.exp(-1) * math.log10(3 * 2**-2)

# %%
result_q3 = term1_q3 + term2_q3 - term3_q3

# %%
result_q3
# Out:
# 4.97610750659898

# %% [markdown]
# #### Q4. log10(e^(x - 2)) - log10(e^x) + log10(10) + e^(-x) * log10(6 * 2^-1)

# %%
x = 4

# %%
term1_q4 = math.log10(math.exp(x-2))

# %%
term2_q4 = math.log10(math.exp(x))

# %%
term3_q4 = math.log10(10)

# %%
term4_q4 = math.exp(-x) * math.log10(6 * 2**-1)

# %%
result_q4 = term1_q4 - term2_q4 + term3_q4 + term4_q4

# %%
result_q4
# Out:
# 0.14014981680108146

# %% [markdown]
# #### Q5. log_2(1 / e^(-x)) + log10(8) - e^(-2) * log10(9 * 2^-3)

# %%
x = 0

# %%
term1_q5 = math.log(1/math.exp(-x), 2)

# %%
term2_q5 = math.log10(8)

# %%
term3_q5 = math.exp(-2) * math.log10(9 * 2 **-3)

# %%
result_q5 = term1_q5 + term2_q5 - term3_q5

# %%
result_q5
# Out:
# 0.89616724587826

# %% [markdown]
# #### Q6. 2e^x * log10(4 * 2^y) + log_2(1 / e^(-x))

# %%
x = -1

# %%
y = 1/2

# %%
term1_q6 = 2 * math.exp(x) * math.log10(4 * 2**y)

# %%
term2_q6 = math.log(1 / math.exp(-x), 2)

# %%
result_q6 = term1_q6 + term2_q6

# %%
result_q6
# Out:
# -0.8889813079854278

# %% [markdown]
# #### Q7. log10(e^x / e^(x + y)) + log_5(125) - e^(-x) * log10(2^-y)

# %%
x = 3/2

# %%
y = -2

# %%
term1_q7 = math.log10(math.exp(x) / math.exp(x + y))

# %%
term2_q7 = math.log(125,5)

# %%
term3_q7 = math.exp(-x) * math.log10(2**(-y))

# %%
result_q7 = term1_q7 + term2_q7 - term3_q7

# %%
result_q7
# Out:
# 3.734251221522533

# %% [markdown]
# #### Q8. log_2(e^(-x)) + y * log10(10) - e^(-y) * log10(3 * 2^x)

# %%
x = -0.5

# %%
y = 2

# %%
term1_q8 = math.log(math.exp(-x), 2)

# %%
term2_q8 = y * math.log10(10)

# %%
term3_q8 = math.exp(-y) * math.log10(3 * 2**x)

# %%
result_q8 = term1_q8 + term2_q8 - term3_q8

# %%
result_q8
# Out:
# 2.677146170161739

# %% [markdown]
# #### Q9. log10(e^x) + log10(5) - y * e^(-x) * log10(2)

# %%
x = 1/3

# %%
y = -1

# %%
term1_q9 = math.log10(math.exp(x))

# %%
term2_q9 = math.log10(5)

# %%
term3_q9 = y * math.exp(-x) * math.log10(2)

# %%
result_q9 = term1_q9 + term2_q9 - term3_q9

# %%
result_q9
# Out:
# 1.0594322489522372

# %% [markdown]
# #### Q10. log_2(1 / e^{-(x + y)}) + e^x * log10(7 * 2^y)

# %%
x = -2

# %%
y = -1/2

# %%
term1_q10 = math.log(1 / math.exp(-(x + y)), 2)

# %%
term2_q10 = math.exp(x) * math.log10( 7 * 2**y)

# %%
result_q10 = term1_q10 + term2_q10

# %%
result_q10
# Out:
# -3.5127360094773237

# %%
a = "  Hello, World!"

# %%
a.strip()
# Out:
# 'Hello, World!'

# %%
print(a.strip())
# Out:
# Hello, World!

# %%
a.replace('H','a')
# Out:
# '  aello, World!'

# %%
print(a.strip().replace('H','m'))
# Out:
# mello, World!

# %%
myVariable = "Hola, como !estas?"

# %%
myVariable.split('!')
# Out:
# ['Hola, como ', 'estas?']

# %%
'welcome'.lower()
# Out:
# 'welcome'

# %%
a = 'Hello'

# %%
b = 'World'

# %%
c = a + b

# %%
print(c)
# Out:
# HelloWorld

# %%
print(a + " " + b)
# Out:
# Hello World

# %%
age = 35

# %%
txt = f"My name is John, I am {age}"

# %%
print(txt)
# Out:
# My name is John, I am 35

# %%
price = 59

# %%
txt = f"The price is {price:.3f}$."

# %%
print(txt)
# Out:
# The price is 59.000$.

# %%
txt = f"The price is {20 * 59}$."

# %%
print(txt)
# Out:
# The price is 1180$.

# %%
text = "This is an \"example\" text"

# %%
print(text)
# Out:
# This is an "example" text

# %%
x = "Hello"

# %%
print(len(x))
# Out:
# 5

# %%
print(bool(1))
# Out:
# True

# %%
x = 5

# %%
x += 3

# %%
print(x)
# Out:
# 8
